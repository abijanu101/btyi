# %%
import sys
sys.path.append('../../')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

# %%
import pandas as pd

from src.config.paths import BILINGUAL_PATH
from src.core.speech import BiASR

# %%
df1 = pd.read_parquet(BILINGUAL_PATH / 'libri-train.parquet')
df2 = pd.read_parquet(BILINGUAL_PATH / 'cvur-train.parquet')

# %%
asr = BiASR()
asr.model.print_params()
# Out:
# CTC Network	 1.90M  	(7.24MB)
# Conformer	 33.56M  	(128.02MB)
# Prediction Net	 2.47M  	(9.43MB)
# Link Network	 0.18M  	(0.69MB)
# Joint Network	 3.08M  	(11.75MB)
# --------------------------------------------------
# Total		 41.19M  	(157.13MB)

# %%
asr.load()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 asr.load()
#
# File e:\Coding\Projects\btyi\scripts\..\src\core\speech\system.py:163, in BiASR.load(self)
#     158 tokenizer_dir = root_dir / 'tokenizer'
#     160 self.tokenizer = ByteLevelBPETokenizer.from_file(
#     161     str(tokenizer_dir / 'vocab.json'), str(tokenizer_dir / 'merges.txt')
#     162 )
# --> 163 checkpoint = torch.load(str(root_dir / 'model.pt'))
#     165 self.model.load_state_dict(checkpoint['model'])
#     166 self.trainer.ctc_trainer.optim.load_state_dict(checkpoint['ctc optim'])
#
# File c:\Users\abi\miniconda3\envs\btyi\Lib\site-packages\torch\serialization.py:1521, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1519 if weights_only:
#    1520     try:
# -> 1521         return _load(
#    1522             opened_zipfile,
# ...

# %%
asr.train_round_robin(df1, df2, 4, 4, 100_000, True)
