# %%
import sys
sys.path.append('../')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.core.speech import BiASR

# %% [markdown]
# # BiASR

# %%
model = BiASR()
model.load()

# %% [markdown]
# ideally you'd use async in the function but i didnt have time

# %%
model.stream(5)
# Out:
# Rough:
# Refined:	 it was the dy of the dy of the dy of the dy of the dy of the dy of the dy of the dy of the dy of the dy of the dy of the dy of
# Rough:
# Refined:	  her dy
# Rough:
# Refined:
# Rough:
# Refined:
# Rough:
# Refined:
# Rough:
# Refined:
# Rough:
# Refined:
# Rough:
# Refined:
# Rough:
# Refined:
# Rough:
# Refined:
