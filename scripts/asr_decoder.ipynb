# %%
import sys
sys.path.append('../')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.core.speech import BiASR

# %%
model = BiASR()
model.load()
# Out:
# Loaded Successfully.

# %%
model.stream(5)
# Out:
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
#
# []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model.stream()
#
# File c:\Users\abi\miniconda3\envs\btyi\Lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File e:\Coding\Projects\btyi\scripts\..\src\core\speech\system.py:46, in BiASR.stream(self, dur_limit, sentinel_phrase)
#      44 stream.start()
#      45 while dur_limit is None or dur_elapsed < dur_limit:
# ---> 46     X, _ = stream.read(STREAM_CHUNK_SAMPLES)
# ...

# %%
model.tokenizer.decode(model.tokenizer.encode("yo").ids)
